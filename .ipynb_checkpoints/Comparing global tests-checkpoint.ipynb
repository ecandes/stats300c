# %% [markdown]
# # Comparison between global tests
#
# In this notebook we compare the power of
#
# *   Bonferroni's test
# *   $\chi^2$ test
# *   Fisher's combination test
#
# against various alternatives.

# %%
import numpy as np
from scipy.stats import chi2
from scipy.stats import norm

# %%
class Test:
    def __init__(self,n=1_000_000,alpha=0.05):
        self.n = n
        self.alpha = alpha
        self.thresh = {'Bonferroni': norm.ppf(1-alpha/2/n),
                       'Chi2' : chi2.ppf(1-alpha,df=n),
                       'Fisher' : chi2.ppf(1-alpha,df=2*n)}

    def theta(self,mu):
        return np.linalg.norm(mu) ** 2 / np.sqrt(2 * self.n)

    def sampleY(self,mu,B):
        self.Y = mu[np.newaxis,:] + np.random.randn(B,n)

    def testValue(self):
        y = self.Y
        pvals = 2 * norm.cdf(-np.abs(y))
        return {'Bonferroni': np.abs(y).max(axis=1) > self.thresh['Bonferroni'],
                'Chi2' : np.sum(y**2,axis=1) > self.thresh['Chi2'],
                'Fisher' : np.sum(-2*np.log(pvals),axis=1) > self.thresh['Fisher']}

    def print_info(self,mu):
        print('Value of Bonferroni Threshold: {:.2f}'.format(self.thresh['Bonferroni']))
        print('Value of theta = ||mu||^2/sqrt(2n): {:.2f}'.format(self.theta(mu)))
        print('Expected power of chi-sq test: {:.2f}'.format(norm.cdf(self.theta(mu) - 1.645)))

    def print_power(self,T):
        for method in T.keys():
            power = T[method].mean()
            print(method + ' power: {:.1f}'.format(100 * power))

# %% [markdown]
# ### Sparse strong effects

# %%
n = 1_000_000
alpha = 0.05
results = Test(n,alpha)

mu = np.zeros(n)
mu[:4] = results.thresh['Bonferroni']
results.print_info(mu)
# Out:
# Value of Bonferroni Threshold: 5.45
# Value of theta = ||mu||^2/sqrt(2n): 0.08
# Expected power of chi-sq test: 0.06

# %% [markdown]
# We can actually guess the power of Bonferroni's method
#
# * $A$ event signal is above noise level: $\mathbb{P}(A) = 1-1/16 = 0.9375$
# * $B$ event noise is above noice level: $\mathbb{P}(B) = q(0.05) \approx 0.0487$
#
# $$
# \mathbb{P}(A \cup B) = \mathbb{P}(A) + \mathbb{P}(B) - \mathbb{P}(A) \mathbb{P}(B) \approx 0.94
# $$

# %% [markdown]
# Let us look at the power of the three tests against this alternative

# %%
results.sampleY(mu,B=500)
T = results.testValue()
results.print_power(T)
# Out:
# Bonferroni power: 94.2
# Chi2 power: 5.4
# Fisher power: 6.2

# %% [markdown]
# ### Distributed weak effects

# %%
k = 2400
mu = np.zeros(n)
mu[:k] = 1.1
results.print_info(mu)
# Out:
# Value of Bonferroni Threshold: 5.45
# Value of theta = ||mu||^2/sqrt(2n): 2.05
# Expected power of chi-sq test: 0.66

# %% [markdown]
# This is an interesting setting because in this case, the maximum value of $Y$ is likely to come from a null.

# %% [markdown]
# Let us look at the power of the three tests against this alternative

# %%
results.sampleY(mu,B=500)
T = results.testValue()
results.print_power(T)
# Out:
# Bonferroni power: 7.8
# Chi2 power: 67.4
# Fisher power: 62.2

# %% [markdown]
# ### Where is the maximum coming from?
#
# Below we plot the distribution of the maximum test statistic for the signal and noise variables separately

# %%
# True distribution

def cdf(t,n,mu=0,absolute=False):
    if absolute:
        log_cdf = n * np.log(norm.cdf(t-mu) - norm.cdf(-t-mu))
    else:
        log_cdf = n * np.log(norm.cdf(t-mu))
        
    return np.exp(log_cdf)

def pdf(t,n,mu=0,absolute=False):
    if absolute:
        return n * (norm.pdf(t-mu) + norm.pdf(-t-mu)) * cdf(t,n-1,mu,absolute)
    else:
        return n * norm.pdf(t-mu) * cdf(t,n-1,mu,absolute)

# %%
n, k = 1_000_000, 2400
mu_amp = 1.1

t = np.linspace(3.5,6.5,1000)

plt.figure(figsize=(8,5))
plt.plot(t,pdf(t,k,mu=1.1),label='signal')
plt.plot(t,pdf(t,n-k),label='noise')

plt.legend()
plt.title('Distribution of test statistic')
plt.show()
